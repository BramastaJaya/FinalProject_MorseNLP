# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\-\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# ### NLTK Libary

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import requests
from bs4 import BeautifulSoup

req = requests.get('https://christophm.github.io/interpretable-ml-book/what-is-machine-learning.html')
bs = BeautifulSoup(req.text)
sia = SentimentIntensityAnalyzer()
text = ''

for i in bs.find_all('p'):
    text += i.text.replace('\n', '')+' '

#display(text)

scores = sia.polarity_scores(text)

for key, value in scores.items():
    print(f"{key}: {value}")
# Out:
# neg: 0.013
# neu: 0.954
# pos: 0.033
# compound: 0.8519

# %% [markdown]
# ### TextBlob Library

# %%
# !uv pip install textblob
# Out:
# Using Python 3.11.15 environment at: e:\10.Codes\IoT\FinalProject_MorseNLP\.conda
# error: Request failed after 3 retries in 126.4s
#   Caused by: Failed to fetch: `https://pypi.org/simple/textblob/`
#   Caused by: error sending request for url (https://pypi.org/simple/textblob/)
#   Caused by: operation timed out
